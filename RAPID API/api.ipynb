# %%
# %pip install requests
# Out:
# Requirement already satisfied: requests in d:\ml practical\repository\venv\lib\site-packages (2.32.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\ml practical\repository\venv\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\ml practical\repository\venv\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\ml practical\repository\venv\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\ml practical\repository\venv\lib\site-packages (from requests) (2024.7.4)
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

company="State Bank Of India"

url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"datatype":"json","keywords":company,"function":"SYMBOL_SEARCH"}

headers = {
	"x-rapidapi-key": "8ad32f0cd3msh6170ca16860d762p160836jsna81fbc877f4b",
	"x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

response.json()
# Out:
# {'bestMatches': [{'1. symbol': 'SBIN.BSE',
#    '2. name': 'State Bank of India',
#    '3. type': 'Equity',
#    '4. region': 'India/Bombay',
#    '5. marketOpen': '09:15',
#    '6. marketClose': '15:30',
#    '7. timezone': 'UTC+5.5',
#    '8. currency': 'INR',
#    '9. matchScore': '1.0000'},
#   {'1. symbol': 'SBKFF',
#    '2. name': 'State Bank of India',
#    '3. type': 'Equity',
#    '4. region': 'United States',
#    '5. marketOpen': '09:30',
#    '6. marketClose': '16:00',
#    '7. timezone': 'UTC-04',
#    '8. currency': 'USD',
#    '9. matchScore': '1.0000'},
#   {'1. symbol': 'SID.FRK',
#    '2. name': 'State Bank of India',
#    '3. type': 'Equity',
#    '4. region': 'Frankfurt',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '20:00',
#    '7. timezone': 'UTC+02',
#    '8. currency': 'EUR',
#    '9. matchScore': '1.0000'},
#   {'1. symbol': 'SBID.LON',
#    '2. name': 'State Bank of India GDR',
#    '3. type': 'Equity',
#    '4. region': 'United Kingdom',
#    '5. marketOpen': '08:00',
#    '6. marketClose': '16:30',
#    '7. timezone': 'UTC+01',
#    '8. currency': 'USD',
#    '9. matchScore': '0.9048'}]}

# %% [markdown]
# Getting the data for state bank of india  from above symbol is SBIN.BSE

# %%
import requests
symbol="SBIN.BSE"
url = "https://alpha-vantage.p.rapidapi.com/query"

querystring = {"function":"TIME_SERIES_DAILY","symbol":symbol,"outputsize":"compact","datatype":"json"}

headers = {
	"x-rapidapi-key": "8ad32f0cd3msh6170ca16860d762p160836jsna81fbc877f4b",
	"x-rapidapi-host": "alpha-vantage.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data=response.json()

# %%
data
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'SBIN.BSE',
#   '3. Last Refreshed': '2024-07-15',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2024-07-15': {'1. open': '860.0000',
#    '2. high': '886.9000',
#    '3. low': '860.0000',
#    '4. close': '881.6000',
#    '5. volume': '1981455'},
#   '2024-07-12': {'1. open': '856.7000',
#    '2. high': '863.4000',
#    '3. low': '855.5000',
#    '4. close': '859.6500',
#    '5. volume': '905757'},
#   '2024-07-11': {'1. open': '854.7000',
#    '2. high': '858.0000',
#    '3. low': '849.5500',
#    '4. close': '856.5500',
#    '5. volume': '481214'},
#   '2024-07-10': {'1. open': '861.0000',
#    '2. high': '861.0000',
#    '3. low': '843.3000',
#    '4. close': '849.1000',
#    '5. volume': '479702'},
#   '2024-07-09': {'1. open': '860.0000',
#    '2. high': '869.9000',
#    '3. low': '855.8500',
#    '4. close': '860.9500',
#    '5. volume': '758991'},
#   '2024-07-08': {'1. open': '859.5000',
#    '2. high': '864.8000',
#    '3. low': '852.9000',
#    '4. close': '856.2500',
#    '5. volume': '1108215'},
#   '2024-07-05': {'1. open': '838.7000',
#    '2. high': '861.5500',
#    '3. low': '837.6500',
#    '4. close': '860.0500',
#    '5. volume': '1499246'},
#   '2024-07-04': {'1. open': '844.6000',
#    '2. high': '844.6000',
#    '3. low': '834.5000',
#    '4. close': '839.2500',
#    '5. volume': '674690'},
#   '2024-07-03': {'1. open': '829.7000',
#    '2. high': '843.8000',
#    '3. low': '825.0500',
#    '4. close': '840.1000',
#    '5. volume': '1672011'},
#   '2024-07-02': {'1. open': '844.8500',
#    '2. high': '846.4500',
#    '3. low': '822.8500',
#    '4. close': '826.3500',
#    '5. volume': '1099939'},
#   '2024-07-01': {'1. open': '850.0000',
#    '2. high': '850.5500',
#    '3. low': '839.9500',
#    '4. close': '842.1000',
#    '5. volume': '1084488'},
#   '2024-06-28': {'1. open': '847.5000',
#    '2. high': '863.7500',
#    '3. low': '844.1500',
#    '4. close': '848.8500',
#    '5. volume': '1916294'},
#   '2024-06-27': {'1. open': '845.0500',
#    '2. high': '847.4000',
#    '3. low': '838.4000',
#    '4. close': '844.1500',
#    '5. volume': '473372'},
#   '2024-06-26': {'1. open': '841.8000',
#    '2. high': '848.6000',
#    '3. low': '836.0000',
#    '4. close': '845.0500',
#    '5. volume': '543783'},
#   '2024-06-25': {'1. open': '838.6500',
#    '2. high': '845.7500',
#    '3. low': '834.9500',
#    '4. close': '841.8500',
#    '5. volume': '538485'},
#   '2024-06-24': {'1. open': '832.7500',
#    '2. high': '836.0500',
#    '3. low': '820.8500',
#    '4. close': '832.6500',
#    '5. volume': '2194566'},
#   '2024-06-21': {'1. open': '845.0000',
#    '2. high': '848.0000',
#    '3. low': '828.6500',
#    '4. close': '836.4000',
#    '5. volume': '1667384'},
#   '2024-06-20': {'1. open': '853.9500',
#    '2. high': '853.9500',
#    '3. low': '842.4000',
#    '4. close': '843.8000',
#    '5. volume': '513158'},
#   '2024-06-19': {'1. open': '846.0500',
#    '2. high': '860.5000',
#    '3. low': '841.0500',
#    '4. close': '852.6000',
#    '5. volume': '1066899'},
#   '2024-06-18': {'1. open': '843.2000',
#    '2. high': '851.5000',
#    '3. low': '840.3500',
#    '4. close': '844.6000',
#    '5. volume': '963912'},
#   '2024-06-14': {'1. open': '844.0000',
#    '2. high': '849.7500',
#    '3. low': '835.9000',
#    '4. close': '840.2000',
#    '5. volume': '1706369'},
#   '2024-06-13': {'1. open': '845.0000',
#    '2. high': '845.7500',
#    '3. low': '836.0000',
#    '4. close': '843.9000',
#    '5. volume': '815906'},
#   '2024-06-12': {'1. open': '837.7000',
#    '2. high': '845.2500',
#    '3. low': '833.0000',
#    '4. close': '839.1500',
#    '5. volume': '610408'},
#   '2024-06-11': {'1. open': '836.7500',
#    '2. high': '839.4500',
#    '3. low': '829.1000',
#    '4. close': '835.2500',
#    '5. volume': '890869'},
#   '2024-06-10': {'1. open': '834.9000',
#    '2. high': '846.0000',
#    '3. low': '829.0000',
#    '4. close': '832.1500',
#    '5. volume': '1655324'},
#   '2024-06-07': {'1. open': '820.5000',
#    '2. high': '831.0000',
#    '3. low': '810.3000',
#    '4. close': '829.9000',
#    '5. volume': '2139387'},
#   '2024-06-06': {'1. open': '802.7500',
#    '2. high': '833.1000',
#    '3. low': '795.7000',
#    '4. close': '816.9500',
#    '5. volume': '1355824'},
#   '2024-06-05': {'1. open': '793.9500',
#    '2. high': '793.9500',
#    '3. low': '744.1000',
#    '4. close': '789.6500',
#    '5. volume': '3953125'},
#   '2024-06-04': {'1. open': '905.8000',
#    '2. high': '905.8000',
#    '3. low': '734.2500',
#    '4. close': '775.2000',
#    '5. volume': '7900395'},
#   '2024-06-03': {'1. open': '867.9500',
#    '2. high': '912.1000',
#    '3. low': '856.8500',
#    '4. close': '905.8000',
#    '5. volume': '3819398'},
#   '2024-05-31': {'1. open': '831.8000',
#    '2. high': '834.4500',
#    '3. low': '817.1000',
#    '4. close': '830.1000',
#    '5. volume': '1053768'},
#   '2024-05-30': {'1. open': '822.9500',
#    '2. high': '836.0000',
#    '3. low': '820.4000',
#    '4. close': '826.0500',
#    '5. volume': '742252'},
#   '2024-05-29': {'1. open': '830.8500',
#    '2. high': '834.4500',
#    '3. low': '819.5500',
#    '4. close': '822.9500',
#    '5. volume': '2180643'},
#   '2024-05-28': {'1. open': '836.8000',
#    '2. high': '840.4500',
#    '3. low': '823.6500',
#    '4. close': '830.9000',
#    '5. volume': '445715'},
#   '2024-05-27': {'1. open': '833.5000',
#    '2. high': '839.4000',
#    '3. low': '823.0000',
#    '4. close': '834.1000',
#    '5. volume': '1143699'},
#   '2024-05-24': {'1. open': '830.9500',
#    '2. high': '841.0000',
#    '3. low': '826.8500',
#    '4. close': '828.6000',
#    '5. volume': '979447'},
#   '2024-05-23': {'1. open': '825.0000',
#    '2. high': '835.4000',
#    '3. low': '822.1000',
#    '4. close': '832.3500',
#    '5. volume': '856598'},
#   '2024-05-22': {'1. open': '827.8500',
#    '2. high': '827.8500',
#    '3. low': '813.6000',
#    '4. close': '819.3000',
#    '5. volume': '594888'},
#   '2024-05-21': {'1. open': '824.8500',
#    '2. high': '836.2000',
#    '3. low': '819.5500',
#    '4. close': '830.5500',
#    '5. volume': '369412'},
#   '2024-05-17': {'1. open': '815.1500',
#    '2. high': '822.4000',
#    '3. low': '811.5000',
#    '4. close': '817.8500',
#    '5. volume': '742324'},
#   '2024-05-16': {'1. open': '825.0000',
#    '2. high': '826.0000',
#    '3. low': '797.5000',
#    '4. close': '811.9000',
#    '5. volume': '827240'},
#   '2024-05-15': {'1. open': '821.9500',
#    '2. high': '825.3500',
#    '3. low': '818.0500',
#    '4. close': '820.4000',
#    '5. volume': '282771'},
#   '2024-05-14': {'1. open': '812.7000',
#    '2. high': '822.0000',
#    '3. low': '808.0000',
#    '4. close': '818.1500',
#    '5. volume': '365478'},
#   '2024-05-13': {'1. open': '819.0000',
#    '2. high': '819.4000',
#    '3. low': '798.6500',
#    '4. close': '808.8500',
#    '5. volume': '1305149'},
#   '2024-05-10': {'1. open': '828.7000',
#    '2. high': '832.1000',
#    '3. low': '815.7000',
#    '4. close': '818.3500',
#    '5. volume': '855049'},
#   '2024-05-09': {'1. open': '813.4500',
#    '2. high': '839.6000',
#    '3. low': '803.5500',
#    '4. close': '819.6500',
#    '5. volume': '1177161'},
#   '2024-05-08': {'1. open': '802.3500',
#    '2. high': '821.8000',
#    '3. low': '799.6500',
#    '4. close': '810.4000',
#    '5. volume': '752735'},
#   '2024-05-07': {'1. open': '811.2000',
#    '2. high': '814.4500',
#    '3. low': '793.3500',
#    '4. close': '801.9500',
#    '5. volume': '352828'},
#   '2024-05-06': {'1. open': '835.0000',
#    '2. high': '835.0000',
#    '3. low': '803.0500',
#    '4. close': '807.7500',
#    '5. volume': '1082721'},
#   '2024-05-03': {'1. open': '834.5000',
#    '2. high': '836.0000',
#    '3. low': '820.1000',
#    '4. close': '831.5500',
#    '5. volume': '843949'},
#   '2024-05-02': {'1. open': '826.6000',
#    '2. high': '833.9500',
#    '3. low': '825.7000',
#    '4. close': '830.0500',
#    '5. volume': '286451'},
#   '2024-04-30': {'1. open': '827.4000',
#    '2. high': '834.6000',
#    '3. low': '820.0000',
#    '4. close': '825.7000',
#    '5. volume': '602010'},
#   '2024-04-29': {'1. open': '809.0000',
#    '2. high': '831.0000',
#    '3. low': '798.7500',
#    '4. close': '826.1500',
#    '5. volume': '1369981'},
#   '2024-04-26': {'1. open': '815.0500',
#    '2. high': '816.8500',
#    '3. low': '799.0000',
#    '4. close': '801.4000',
#    '5. volume': '848439'},
#   '2024-04-25': {'1. open': '769.0000',
#    '2. high': '814.4500',
#    '3. low': '769.0000',
#    '4. close': '812.6000',
#    '5. volume': '1634667'},
#   '2024-04-24': {'1. open': '778.1000',
#    '2. high': '778.1000',
#    '3. low': '770.3500',
#    '4. close': '773.2000',
#    '5. volume': '262806'},
#   '2024-04-23': {'1. open': '771.8500',
#    '2. high': '777.5000',
#    '3. low': '765.8500',
#    '4. close': '772.8500',
#    '5. volume': '255601'},
#   '2024-04-22': {'1. open': '754.9500',
#    '2. high': '768.9500',
#    '3. low': '750.4500',
#    '4. close': '765.8500',
#    '5. volume': '871015'},
#   '2024-04-19': {'1. open': '735.3000',
#    '2. high': '752.2500',
#    '3. low': '732.0500',
#    '4. close': '750.8000',
#    '5. volume': '1018883'},
#   '2024-04-18': {'1. open': '752.2500',
#    '2. high': '759.9500',
#    '3. low': '742.2000',
#    '4. close': '744.8000',
#    '5. volume': '708924'},
#   '2024-04-16': {'1. open': '750.6000',
#    '2. high': '754.9000',
#    '3. low': '744.5000',
#    '4. close': '751.9000',
#    '5. volume': '539562'},
#   '2024-04-15': {'1. open': '751.5000',
#    '2. high': '763.0000',
#    '3. low': '748.5000',
#    '4. close': '756.8500',
#    '5. volume': '719175'},
#   '2024-04-12': {'1. open': '778.9500',
#    '2. high': '779.5000',
#    '3. low': '764.6500',
#    '4. close': '766.7500',
#    '5. volume': '911540'},
#   '2024-04-10': {'1. open': '767.7500',
#    '2. high': '780.7000',
#    '3. low': '763.9000',
#    '4. close': '779.0000',
#    '5. volume': '346439'},
#   '2024-04-09': {'1. open': '768.0000',
#    '2. high': '772.4500',
#    '3. low': '761.1000',
#    '4. close': '764.1500',
#    '5. volume': '1047810'},
#   '2024-04-08': {'1. open': '767.6500',
#    '2. high': '770.0000',
#    '3. low': '761.8500',
#    '4. close': '768.4000',
#    '5. volume': '391601'},
#   '2024-04-05': {'1. open': '758.8500',
#    '2. high': '766.2000',
#    '3. low': '752.7000',
#    '4. close': '764.3500',
#    '5. volume': '574320'},
#   '2024-04-04': {'1. open': '775.0000',
#    '2. high': '775.0000',
#    '3. low': '758.0000',
#    '4. close': '759.2500',
#    '5. volume': '321746'},
#   '2024-04-03': {'1. open': '765.7000',
#    '2. high': '772.0000',
#    '3. low': '760.0500',
#    '4. close': '770.9500',
#    '5. volume': '517017'},
#   '2024-04-02': {'1. open': '758.9500',
#    '2. high': '768.8000',
#    '3. low': '753.3500',
#    '4. close': '767.3500',
#    '5. volume': '285536'},
#   '2024-04-01': {'1. open': '759.8000',
#    '2. high': '761.7000',
#    '3. low': '752.0500',
#    '4. close': '758.2000',
#    '5. volume': '617725'},
#   '2024-03-28': {'1. open': '738.7000',
#    '2. high': '759.5500',
#    '3. low': '736.8000',
#    '4. close': '752.6000',
#    '5. volume': '873887'},
#   '2024-03-27': {'1. open': '742.6000',
#    '2. high': '745.8000',
#    '3. low': '730.1500',
#    '4. close': '734.0500',
#    '5. volume': '441567'},
#   '2024-03-26': {'1. open': '744.9500',
#    '2. high': '747.5000',
#    '3. low': '738.1500',
#    '4. close': '740.0500',
#    '5. volume': '6074241'},
#   '2024-03-22': {'1. open': '743.3000',
#    '2. high': '749.0000',
#    '3. low': '741.5500',
#    '4. close': '746.4000',
#    '5. volume': '656117'},
#   '2024-03-21': {'1. open': '742.8000',
#    '2. high': '750.5500',
#    '3. low': '740.5500',
#    '4. close': '743.8000',
#    '5. volume': '472692'},
#   '2024-03-20': {'1. open': '724.5000',
#    '2. high': '738.9000',
#    '3. low': '720.0000',
#    '4. close': '736.3000',
#    '5. volume': '342014'},
#   '2024-03-19': {'1. open': '730.9500',
#    '2. high': '734.2000',
#    '3. low': '721.2500',
#    '4. close': '723.1000',
#    '5. volume': '176073'},
#   '2024-03-18': {'1. open': '726.4000',
#    '2. high': '737.9000',
#    '3. low': '722.2000',
#    '4. close': '730.7000',
#    '5. volume': '549342'},
#   '2024-03-15': {'1. open': '740.5000',
#    '2. high': '746.6000',
#    '3. low': '723.0500',
#    '4. close': '732.0000',
#    '5. volume': '855356'},
#   '2024-03-14': {'1. open': '750.9000',
#    '2. high': '750.9000',
#    '3. low': '734.0500',
#    '4. close': '740.7500',
#    '5. volume': '388377'},
#   '2024-03-13': {'1. open': '759.3500',
#    '2. high': '763.7000',
#    '3. low': '743.2000',
#    '4. close': '746.4000',
#    '5. volume': '403736'},
#   '2024-03-12': {'1. open': '770.0000',
#    '2. high': '777.6500',
#    '3. low': '757.5000',
#    '4. close': '759.4000',
#    '5. volume': '417860'},
#   '2024-03-11': {'1. open': '788.6500',
#    '2. high': '792.8000',
#    '3. low': '770.7000',
#    '4. close': '773.5000',
#    '5. volume': '603641'},
#   '2024-03-07': {'1. open': '788.3500',
#    '2. high': '793.5000',
#    '3. low': '782.9500',
#    '4. close': '788.1500',
#    '5. volume': '773604'},
#   '2024-03-06': {'1. open': '784.7500',
#    '2. high': '790.1500',
#    '3. low': '772.9000',
#    '4. close': '784.0500',
#    '5. volume': '458020'},
#   '2024-03-05': {'1. open': '770.0000',
#    '2. high': '786.9000',
#    '3. low': '769.0500',
#    '4. close': '783.9000',
#    '5. volume': '776880'},
#   '2024-03-04': {'1. open': '774.9000',
#    '2. high': '776.8000',
#    '3. low': '769.0500',
#    '4. close': '772.1500',
#    '5. volume': '553231'},
#   '2024-03-01': {'1. open': '753.9500',
#    '2. high': '771.8500',
#    '3. low': '752.4000',
#    '4. close': '769.3000',
#    '5. volume': '1205254'},
#   '2024-02-29': {'1. open': '744.9000',
#    '2. high': '754.0000',
#    '3. low': '737.3500',
#    '4. close': '749.3000',
#    '5. volume': '372531'},
#   '2024-02-28': {'1. open': '749.7000',
#    '2. high': '756.7000',
#    '3. low': '741.0000',
#    '4. close': '742.3500',
#    '5. volume': '234215'},
#   '2024-02-27': {'1. open': '759.0000',
#    '2. high': '762.3000',
#    '3. low': '742.4000',
#    '4. close': '749.7000',
#    '5. volume': '2136050'},
#   '2024-02-26': {'1. open': '755.0000',
#    '2. high': '766.2000',
#    '3. low': '752.6000',
#    '4. close': '759.0000',
#    '5. volume': '667473'},
#   '2024-02-23': {'1. open': '766.8500',
#    '2. high': '770.2500',
#    '3. low': '755.2000',
#    '4. close': '759.4000',
#    '5. volume': '1157557'},
#   '2024-02-22': {'1. open': '773.0000',
#    '2. high': '773.5500',
#    '3. low': '757.0000',
#    '4. close': '765.9500',
#    '5. volume': '729181'},
#   '2024-02-21': {'1. open': '761.7500',
#    '2. high': '777.5000',
#    '3. low': '760.0000',
#    '4. close': '771.5500',
#    '5. volume': '1762589'},
#   '2024-02-20': {'1. open': '759.0000',
#    '2. high': '763.3000',
#    '3. low': '753.9000',
#    '4. close': '760.1000',
#    '5. volume': '261103'},
#   '2024-02-19': {'1. open': '757.0500',
#    '2. high': '764.9000',
#    '3. low': '750.0000',
#    '4. close': '759.1000',
#    '5. volume': '702842'},
#   '2024-02-16': {'1. open': '763.9000',
#    '2. high': '774.7000',
#    '3. low': '753.1500',
#    '4. close': '754.7500',
#    '5. volume': '1233883'},
#   '2024-02-15': {'1. open': '746.7000',
#    '2. high': '763.9000',
#    '3. low': '741.7000',
#    '4. close': '761.6000',
#    '5. volume': '785800'}}}

# %%
data.keys()
# Out:
# dict_keys(['Meta Data', 'Time Series (Daily)'])
